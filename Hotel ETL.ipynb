# %%
import pandas as pd 
import numpy as np 
import sqlalchemy as sal

# %%
hotel_data_2018 = pd.read_excel(r"C:\Users\wanji\Desktop\Hotel Data\Hotel-DB\hotel_revenue_historical_full-2.xlsx")
hotel_data_2018
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            1         85               2018
# 1      Resort Hotel            1         75               2018
# 2      Resort Hotel            1         23               2018
# 3      Resort Hotel            1         60               2018
# 4      Resort Hotel            1         96               2018
# ...             ...          ...        ...                ...
# 21991    City Hotel            1         24               2018
# 21992    City Hotel            1          1               2018
# 21993    City Hotel            1         66               2018
# 21994    City Hotel            1         54               2018
# 21995    City Hotel            1         54               2018
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
hotel_data_2019 = pd.read_excel(r"C:\Users\wanji\Desktop\Hotel Data\Hotel-DB\hotel_revenue_historical_full-2.xlsx",'2019')
hotel_data_2019
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            1         20               2019
# 1      Resort Hotel            1         76               2019
# 2      Resort Hotel            1        113               2019
# 3      Resort Hotel            1        113               2019
# 4      Resort Hotel            1        113               2019
# ...             ...          ...        ...                ...
# 79259  Resort Hotel            1         61               2019
# 79260  Resort Hotel            1        219               2019
# 79261  Resort Hotel            1        219               2019
# 79262  Resort Hotel            1        219               2019
# 79263  Resort Hotel            1        118               2019
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                January                         1                          1
# ...

# %%
hotel_data_2020 = pd.read_excel(r"C:\Users\wanji\Desktop\Hotel Data\Hotel-DB\hotel_revenue_historical_full-2.xlsx", '2020')
hotel_data_2020
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            1         74               2020
# 1      Resort Hotel            1         62               2020
# 2      Resort Hotel            1         62               2020
# 3      Resort Hotel            1         62               2020
# 4      Resort Hotel            1         71               2020
# ...             ...          ...        ...                ...
# 40682    City Hotel            1          1               2020
# 40683    City Hotel            1         31               2020
# 40684    City Hotel            1         25               2020
# 40685    City Hotel            1          6               2020
# 40686    City Hotel            1          0               2020
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                January                         1                          1
# ...

# %%
meal_cost = pd.read_excel(r"C:\Users\wanji\Desktop\Hotel Data\Hotel-DB\hotel_revenue_historical_full-2.xlsx", 'meal_cost')
meal_cost
# Out:
#     Cost       meal
# 0   0.00  Undefined
# 1  12.99         BB
# 2  17.99         HB
# 3  21.99         FB
# 4  35.00         SC

# %%
market_segment = pd.read_excel(r"C:\Users\wanji\Desktop\Hotel Data\Hotel-DB\hotel_revenue_historical_full-2.xlsx", 'market_segment')
market_segment
# Out:
#    Discount market_segment
# 0      0.00      Undefined
# 1      0.10         Direct
# 2      0.10         Groups
# 3      0.15      Corporate
# 4      0.20       Aviation
# 5      0.30  Offline TA/TO
# 6      0.30      Online TA
# 7      1.00  Complementary

# %%
# Load the data to the sql server 
import sqlalchemy as sal

# Define your PostgreSQL details
username = 'postgres'
password = 'Edna90!'
hostname = 'localhost'
port = '5432'

# %%
# Create the SQLAlchemy engine
engine = sal.create_engine(f'postgresql+psycopg2://{username}:{password}@{hostname}:{port}/postgres')

# Write hotel data for each year to hotel_table
hotel_data_2018.to_sql('hotel_table', con=engine, if_exists='append', index=False)
# Out:
# 996

# %%
hotel_data_2019.to_sql('hotel_table', con=engine, if_exists='append', index=False)
# Out:
# 264

# %%
hotel_data_2020.to_sql('hotel_table', con=engine, if_exists='append', index=False)
# Out:
# 687

# %%
# Write meal_cost and market_segment data
meal_cost.to_sql('meal_cost', con=engine, if_exists='replace', index=False)
# Out:
# 5

# %%
market_segment.to_sql('market_segment', con=engine, if_exists='replace', index=False)
# Out:
# 8

# %%
# # Function to query and display data
# def query_and_display(query):
#     result = engine.execute(query)
#     for row in result:
#         print(row)

# # Query samples
# query_hotel_table = "SELECT * FROM hotel_table LIMIT 10;"
# query_meal_cost = "SELECT * FROM meal_cost;"
# query_market_segment = "SELECT * FROM market_segment;"

# print("Sample data from hotel_table:")
# query_and_display(query_hotel_table)

# print("\nSample data from meal_cost:")
# query_and_display(query_meal_cost)

# print("\nSample data from market_segment:")
# query_and_display(query_market_segment)
